# %%
pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Using cached psycopg2-binary-2.9.10.tar.gz (385 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: psycopg2-binary
#   Building wheel for psycopg2-binary (setup.py) ... done
#   Created wheel for psycopg2-binary: filename=psycopg2_binary-2.9.10-cp310-cp310-macosx_11_0_arm64.whl size=133635 sha256=8d9b876ddafee161ba88d5dc891a09c08cef99dbcdaa11e215afa71e43540fa1
#   Stored in directory: /Users/bagsolmi/Library/Caches/pip/wheels/bd/8b/58/ff5a880b960d71f645b3679b454f33612254cc39ecdcd6cc5a
# Successfully built psycopg2-binary
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.10
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /opt/anaconda3/envs/pb/lib/python3.10/site-packages (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## POSTGRES 데이터베이스 연동하기

# %%
import psycopg2
from dotenv import load_dotenv
import os

# %%
# .env 파일 로드
load_dotenv()

# 환경 변수에서 값 가져오기 (DB연결)
conn = psycopg2.connect(
    host=os.getenv("DB_HOST"),
    database=os.getenv("DB_NAME"),
    user=os.getenv("DB_USER"),
    password=os.getenv("DB_PASSWORD")
)

cur = conn.cursor() # 쿼리를 실행할 커서 객체 생성
cur.execute("SELECT * FROM country WHERE name = 'United States'")
rows = cur.fetchall()
for row in rows:
    print(row)
# cur.close()
# Out:
# ('USA', 'United States', 'North America', 'North America', 9363520.0, 1776, 278357000, 77.1, Decimal('8510700.00'), Decimal('8110900.00'), 'United States', 'Federal Republic', 'George W. Bush', 3813, 'US')

# %%
import pandas as pd
pd.read_sql("SELECT * FROM city", conn)
# Out:
# /var/folders/xw/2xv7101s71s4jcv2bxrz47rh0000gn/T/ipykernel_9664/1841372258.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("SELECT * FROM city", conn)
#         id            name countrycode       district  population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %% [markdown]
# ### 1. SELECT 실습 : 인구가 가장 많은 도시 10개 출력

# %%
cr = conn.cursor()

# %%
q = """
SELECT name, population
FROM city
ORDER BY population DESC
LIMIT 10
"""
cr.execute(q)
rows = cr.fetchall()
# 결과 출력
for name, population in rows:
    print(f"{name}: {population:,}명")
# Out:
# Mumbai (Bombay): 10,500,000명
# Seoul: 9,981,619명
# São Paulo: 9,968,485명
# Shanghai: 9,696,300명
# Jakarta: 9,604,900명
# Karachi: 9,269,265명
# Istanbul: 8,787,958명
# Ciudad de México: 8,591,309명
# Moscow: 8,389,200명
# New York: 8,008,278명

# %% [markdown]
# ### 2. INSERT 실습

# %%
q = '''INSERT INTO public.city (id, name, countrycode, district, population)
VALUES ({}, '{}', '{}', '{}', {})'''
cr.execute(q.format(99997, 'test city3', 'KOR', 'test 3', 200000))

# %%
conn.commit() # 변경사항을 커밋

# %%
# 데이터 삽입 후 반영 여부 확인
cr.execute("SELECT * FROM city WHERE id = 99997")
row = cr.fetchone()

if row:
    print("✅ INSERT 성공! 데이터:")
    print(row)
else:
    print("❌ INSERT 실패 또는 커밋 안 됨.")
# Out:
# ✅ INSERT 성공! 데이터:
# (99997, 'test city3', 'KOR', 'test 3', 200000)

# %% [markdown]
# ### 3. DELETE 실습

# %%
q = "DELETE FROM city WHERE id = %s"
cr.execute(q, (99997,))

conn.commit()  # 삭제 반영

# %%
cr.execute("SELECT * FROM city WHERE id = %s", (99997,))
row = cr.fetchone()

if row:
    print("❌ 삭제 실패. 데이터가 아직 존재합니다.")
else:
    print("✅ 삭제 성공! 데이터가 더 이상 존재하지 않습니다.")
# Out:
# ✅ 삭제 성공! 데이터가 더 이상 존재하지 않습니다.

# %% [markdown]
# ## 크롤링 데이터 활용하기

# %% [markdown]
# ### 크롤링 해 온 yes24 데이터를 book 테이블에 INSERT하기

# %%
pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/pb/lib/python3.10/site-packages (from beautifulsoup4) (4.13.2)
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.13.4 soupsieve-2.7
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import requests

# %%
url='https://www.yes24.com/product/category/bestseller?categoryNumber=001001003&pageNumber=1&pageSize=120'
resp = requests.get(url)
# yes_bs = bs4.BeautifulSoup(resp.text)
yes_bs = BeautifulSoup(resp.text, 'html.parser')
div_list = yes_bs.find_all('div', {'class':'item_info'})
book_list = []
for div in div_list:
    temp = {}
    temp['title'] = div.find('a', {'class':'gd_name'}).text
    temp['writer'] = div.find('div', {'class':'info_row info_pubGrp'}).find_all('span')[0].text.strip()
    temp['pub'] = div.find('div', {'class':'info_row info_pubGrp'}).find_all('span')[1].text
    temp['pub_date'] = div.find('div', {'class':'info_row info_pubGrp'}).find_all('span')[2].text
    temp['price'] = div.find('em', {'class':'yes_b'}).text
    if div.find('span', {'class':'rating_grade'}):
        temp['review'] = div.find('span', {'class':'rating_grade'}).find('em').text
    else:
        temp['review'] = None
    book_list.append(temp)

# %%
book_list
# Out:
# [{'title': '커서 AI 트렌드&활용백과',
#   'writer': '서승완 저',
#   'pub': '스마트북스',
#   'pub_date': '2025년 03월',
#   'price': '22,500',
#   'review': '9.6'},
#  {'title': '된다! 조회수 터지는 유튜브 쇼츠 만들기',
#   'writer': '최지영 저',
#   'pub': '이지스퍼블리싱',
#   'pub_date': '2025년 04월',
#   'price': '19,800',
#   'review': '10.0'},
#  {'title': '이게 되네? 챗GPT 미친 활용법 71제',
#   'writer': '오힘찬 저',
#   'pub': '골든래빗',
#   'pub_date': '2025년 01월',
#   'price': '21,600',
#   'review': '9.6'},
#  {'title': '진짜 쓰는 실무 엑셀',
#   'writer': '전진권 저',
#   'pub': '제이펍',
#   'pub_date': '2022년 02월',
#   'price': '18,900',
#   'review': '9.8'},
#  {'title': '주니어 백엔드 개발자가 반드시 알아야 할 실무 지식',
#   'writer': '최범균 저',
#   'pub': '한빛미디어',
#   'pub_date': '2025년 04월',
#   'price': '25,200',
#   'review': None},
#  {'title': '비트코인의 시대',
#   'writer': '김창익 저',
#   'pub': '다산북스',
#   'pub_date': '2025년 04월',
#   'price': '22,500',
#   'review': '10.0'},
#  {'title': '요즘 교사를 위한 AI 수업 활용 가이드 with 2022 개정 교육과정',
#   'writer': '박진환, 공지훈, 서원진 저',
#   'pub': '한빛미디어',
#   'pub_date': '2025년 05월',
#   'price': '18,000',
#   'review': '10.0'},
#  {'title': '된다! 하루 만에 끝내는 챗GPT 활용법',
#   'writer': '프롬프트 크리에이터 저',
#   'pub': '이지스퍼블리싱',
#   'pub_date': '2024년 07월',
#   'price': '15,480',
#   'review': '9.4'},
#  {'title': '챗GPT 일타강사의 직장인 업무 만렙 공략집',
#   'writer': '이승필 저',
#   'pub': '한빛미디어',
#   'pub_date': '2025년 03월',
#   'price': '21,600',
#   'review': '9.5'},
#  {'title': 'Do it! 점프 투 파이썬',
#   'writer': '박응용 저',
#   'pub': '이지스퍼블리싱',
#   'pub_date': '2023년 06월',
#   'price': '19,800',
#   'review': '9.8'},
#  {'title': 'AI 리터러시 : 인공지능 필수 지식부터 완벽 활용까지',
#   'writer': '김용성 저',
#   'pub': '프리렉',
#   'pub_date': '2024년 12월',
#   'price': '22,500',
#   'review': '9.7'},
#  {'title': '맛있는 디자인 포토샵 CC 2024',
#   'writer': '윤이사라, 김신애 저',
#   'pub': '한빛미디어',
#   'pub_date': '2024년 03월',
#   'price': '22,500',
#   'review': '9.7'},
#  {'title': '조코딩의 AI 비트코인 자동 매매 시스템 만들기',
#   'writer': '조동근 저',
#   'pub': '한빛미디어',
#   'pub_date': '2025년 04월',
#   'price': '26,100',
#   'review': None},
#  {'title': '마법 같은 영상 제작을 위한 스마트폰 촬영 및 편집 with 캡컷',
#   'writer': '김지희 저',
#   'pub': '시프트',
#   'pub_date': '2025년 03월',
#   'price': '20,700',
#   'review': '10.0'},
#  {'title': '아이패드 드로잉으로 기록하는 일상의 조각들',
#   'writer': '이이오 저',
#   'pub': '한빛라이프',
#   'pub_date': '2025년 05월',
#   'price': '19,800',
#   'review': '10.0'},
#  {'title': '업무시간을 반으로 줄이는 챗GPT 글쓰기',
#   'writer': '정태일 저',
#   'pub': '천그루숲',
#   'pub_date': '2025년 04월',
#   'price': '16,200',
#   'review': '9.8'},
#  {'title': '공여사들의 엑셀 혁명 with 챗GPT',
#   'writer': '공여사들 저',
#   'pub': '한빛미디어',
#   'pub_date': '2025년 03월',
#   'price': '18,900',
#   'review': '9.9'},
#  {'title': '처음이지만 프로처럼 쓰는 노션(Notion)',
#   'writer': '박한용 저',
#   'pub': '디지털북스',
#   'pub_date': '2025년 04월',
#   'price': '19,800',
#   'review': '10.0'},
#  {'title': '기계는 왜 학습하는가',
#   'writer': '아닐 아난타스와미 저/노승영 역',
#   'pub': '까치(까치글방)',
#   'pub_date': '2025년 02월',
#   'price': '22,500',
#   'review': '9.7'},
#  {'title': '소프트웨어 사고력 올림피아드',
#   'writer': '구덕회 저',
#   'pub': '잇플ITPLE',
#   'pub_date': '2023년 08월',
#   'price': '25,650',
#   'review': '8.3'},
#  {'title': '회사에서 바로 통하는 실무 엑셀+파워포인트+워드&한글',
#   'writer': '전미진, 이화진, 신면철 저',
#   'pub': '한빛미디어',
#   'pub_date': '2022년 05월',
#   'price': '19,800',
#   'review': '9.6'},
#  {'title': '혼자 공부하는 파이썬',
#   'writer': '윤인성 저',
#   'pub': '한빛미디어',
#   'pub_date': '2022년 06월',
#   'price': '19,800',
#   'review': '9.5'},
#  {'title': '네이버 블로그 AI 자동화 마케팅 with 챗GPT+Zapier+Make',
#   'writer': '조영빈 저',
#   'pub': '디지털북스',
#   'pub_date': '2025년 04월',
#   'price': '18,000',
#   'review': '10.0'},
#  {'title': '교사를 위한 패들렛 Padlet',
#   'writer': '안익재 저',
#   'pub': '앤써북',
#   'pub_date': '2025년 03월',
#   'price': '15,120',
#   'review': '10.0'},
#  {'title': '마인크래프트 초보자 가이드 New Edition',
#   'writer': 'Mojang Studio 저/이주안 역',
#   'pub': '영진닷컴',
#   'pub_date': '2024년 04월',
#   'price': '13,500',
#   'review': '9.8'},
#  {'title': '숏폼 영상 편집 제작 및 수익 창출 with 캡컷 · 생성형 AI',
#   'writer': '채수창 저',
#   'pub': '앤써북',
#   'pub_date': '2025년 05월',
#   'price': '12,420',
#   'review': '10.0'},
#  {'title': '혼자 공부하는 컴퓨터 구조+운영체제',
#   'writer': '강민철 저',
#   'pub': '한빛미디어',
#   'pub_date': '2022년 08월',
#   'price': '25,200',
#   'review': '9.8'},
#  {'title': 'Google로 칼퇴하는 교사들의 시크릿',
#   'writer': '김학민, 강경욱, 유병선, 이민재, 이석 저 외 1명\r\n                                        \n정보 더 보기/감추기\n\n\n\n김학민\n강경욱\n유병선\n이민재\n이석\n차수미',
#   'pub': '\n정보 더 보기/감추기\n\n\n\n김학민\n강경욱\n유병선\n이민재\n이석\n차수미\n\n\n\n',
#   'pub_date': '정보 더 보기/감추기',
#   'price': '16,200',
#   'review': '10.0'},
#  {'title': '7가지 프로젝트로 배우는 LLM AI 에이전트 개발',
#   'writer': '황자 저/김진호 역',
#   'pub': '제이펍',
#   'pub_date': '2025년 04월',
#   'price': '32,400',
#   'review': '10.0'},
#  {'title': '요즘 우아한 AI 개발',
#   'writer': '우아한형제들 저',
#   'pub': '골든래빗',
#   'pub_date': '2025년 04월',
#   'price': '21,600',
#   'review': '9.6'},
#  {'title': '진짜 쓰는 프리미어 프로 영상 편집 2025',
#   'writer': '조블리 저',
#   'pub': '제이펍',
#   'pub_date': '2025년 02월',
#   'price': '23,400',
#   'review': '9.8'},
#  {'title': '혼자 공부하는 머신러닝+딥러닝',
#   'writer': '박해선 저',
#   'pub': '한빛미디어',
#   'pub_date': '2025년 04월',
#   'price': '28,800',
#   'review': '9.7'},
#  {'title': '비트코인 백서 해설',
#   'writer': '사토시 나카모토 저/필레몬, 바우키스 역',
#   'pub': '필레우시스',
#   'pub_date': '2025년 02월',
#   'price': '35,100',
#   'review': '10.0'},
#  {'title': '마인크래프트 몹 완벽 가이드',
#   'writer': 'Mojang Studio 저/이주안 역',
#   'pub': '영진닷컴',
#   'pub_date': '2024년 04월',
#   'price': '16,200',
#   'review': '9.5'},
#  {'title': '혼자 공부하는 C 언어',
#   'writer': '서현우 저',
#   'pub': '한빛미디어',
#   'pub_date': '2023년 05월',
#   'price': '23,400',
#   'review': '9.6'},
#  {'title': '멀티패러다임 프로그래밍',
#   'writer': '유인동 저',
#   'pub': '한빛미디어',
#   'pub_date': '2025년 04월',
#   'price': '34,200',
#   'review': '9.0'},
#  {'title': '구글 시트로 스마트한 학교 만들기 : 교사를 위한 스프레드시트 활용 가이드',
#   'writer': '지미정, 장성진, 유병선 저',
#   'pub': '앤써북',
#   'pub_date': '2025년 04월',
#   'price': '21,960',
#   'review': '9.8'},
#  {'title': '챗GPT, 글쓰기 코치가 되어 줘',
#   'writer': '이석현 저',
#   'pub': '제이펍',
#   'pub_date': '2025년 04월',
#   'price': '19,800',
#   'review': '9.9'},
#  {'title': '누구나 아는 나만 모르는 엑셀',
#   'writer': '이성원 저',
#   'pub': '한빛미디어',
#   'pub_date': '2024년 11월',
#   'price': '15,300',
#   'review': '9.9'},
#  {'title': '혼자 해도 프로 선생님처럼 잘 만드는 학교 수업 자료 with 캔바 Canva',
#   'writer': '김태훈, 김한나, 김예슬, 손민지, 유수근 저',
#   'pub': '한빛미디어',
#   'pub_date': '2024년 10월',
#   'price': '20,700',
#   'review': '9.9'},
#  {'title': '정말 쉽네? 챗GPT 입문',
#   'writer': '오힘찬 저',
#   'pub': '골든래빗',
#   'pub_date': '2024년 10월',
#   'price': '19,800',
#   'review': '9.7'},
#  {'title': '밑바닥부터 시작하는 딥러닝 1',
#   'writer': '사이토 고키 저/개앞맵시 역',
#   'pub': '한빛미디어',
#   'pub_date': '2025년 01월',
#   'price': '23,400',
#   'review': '9.2'},
#  {'title': '맛있는 디자인 포토샵 CC 2025',
#   'writer': '윤이사라, 김신애 저',
#   'pub': '한빛미디어',
#   'pub_date': '2025년 03월',
#   'price': '22,500',
#   'review': '10.0'},
#  {'title': '디자인 구구단',
#   'writer': '에이핫 저',
#   'pub': '길벗',
#   'pub_date': '2024년 08월',
#   'price': '18,000',
#   'review': '9.6'},
#  {'title': 'AI 영상 제작',
#   'writer': '민지영, 문수민, 전은재, 앤미디어 저',
#   'pub': '길벗',
#   'pub_date': '2024년 06월',
#   'price': '22,500',
#   'review': '9.8'},
#  {'title': '회사는 엑셀을 가르쳐주지 않아요',
#   'writer': '쏘피(박성희) 저',
#   'pub': '메가스터디북스',
#   'pub_date': '2022년 09월',
#   'price': '16,200',
#   'review': '9.7'},
#  {'title': '챗대리의 따라하면 바로 되는 AI 마케팅 자동화',
#   'writer': '챗대리 저',
#   'pub': '로드북',
#   'pub_date': '2025년 03월',
#   'price': '21,600',
#   'review': '10.0'},
#  {'title': '맥킨지의 로지컬 라이팅',
#   'writer': '아카바 유지 저/이지현 역',
#   'pub': '유엑스리뷰',
#   'pub_date': '2025년 04월',
#   'price': '20,700',
#   'review': '9.7'},
#  {'title': 'Do it! LLM을 활용한 AI 에이전트 개발 입문',
#   'writer': '이성용 저',
#   'pub': '이지스퍼블리싱',
#   'pub_date': '2025년 05월',
#   'price': '31,500',
#   'review': None},
#  {'title': 'DuckDB 인 액션',
#   'writer': '마크 니드햄, 마이클 헝거, 마이클 시몬스 저/김의윤 역',
#   'pub': '인사이트(insight)',
#   'pub_date': '2025년 05월',
#   'price': '25,200',
#   'review': None},
#  {'title': '진짜 챗GPT 활용법',
#   'writer': '김준성, 브라이스 유, 안상준 저',
#   'pub': '위키북스',
#   'pub_date': '2025년 04월',
#   'price': '18,000',
#   'review': None},
#  {'title': '인스타그램 마케팅으로 돈벌기',
#   'writer': '최영인 저',
#   'pub': '성안당',
#   'pub_date': '2025년 04월',
#   'price': '22,500',
#   'review': '9.9'},
#  {'title': '마인크래프트 건축 가이드 미니 프로젝트',
#   'writer': 'Mojang Studio 저/이주안 역',
#   'pub': '영진닷컴',
#   'pub_date': '2021년 05월',
#   'price': '10,800',
#   'review': '9.8'},
#  {'title': '실무에 바로 쓰는 일잘러의 보고서 작성법',
#   'writer': '김마라 저',
#   'pub': '제이펍',
#   'pub_date': '2020년 11월',
#   'price': '16,200',
#   'review': '9.6'},
#  {'title': '네이버 스마트스토어 운영하기',
#   'writer': '서미진 저',
#   'pub': '한빛미디어',
#   'pub_date': '2025년 05월',
#   'price': '18,900',
#   'review': '10.0'},
#  {'title': '이게 되네? 챗GPT 미친 크롤링 24제',
#   'writer': '박현규 저',
#   'pub': '골든래빗',
#   'pub_date': '2025년 04월',
#   'price': '23,400',
#   'review': '10.0'},
#  {'title': '모던 소프트웨어 엔지니어링',
#   'writer': '데이비드 팔리 저/박재호 역',
#   'pub': '책만',
#   'pub_date': '2025년 04월',
#   'price': '25,200',
#   'review': '8.0'},
#  {'title': '된다! 하루 만에 준비하는 AI 학교 수업 활용법',
#   'writer': '정인걸, 김경수 저',
#   'pub': '이지스퍼블리싱',
#   'pub_date': '2025년 03월',
#   'price': '17,820',
#   'review': '10.0'},
#  {'title': '혼자 만들면서 공부하는 파이썬',
#   'writer': '문현일 저',
#   'pub': '한빛미디어',
#   'pub_date': '2025년 02월',
#   'price': '23,400',
#   'review': '9.7'},
#  {'title': '20가지 템플릿으로 배우는 노션 Notion',
#   'writer': '전시진 저',
#   'pub': '시프트',
#   'pub_date': '2024년 10월',
#   'price': '18,000',
#   'review': '9.7'},
#  {'title': '챗GPT·퍼플렉시티·클로드·코파일럿·제미나이 다 잘함',
#   'writer': '이호정 저',
#   'pub': '리코멘드',
#   'pub_date': '2025년 01월',
#   'price': '21,600',
#   'review': '10.0'},
#  {'title': 'RAG 마스터 : 랭체인으로 완성하는 LLM 서비스',
#   'writer': '브라이스 유, 조경아, 박수진, 김재웅 저',
#   'pub': '프리렉',
#   'pub_date': '2025년 04월',
#   'price': '28,800',
#   'review': '10.0'},
#  {'title': '선생님을 위한 캔바 수업 활용',
#   'writer': '김민주 저',
#   'pub': '앤써북',
#   'pub_date': '2025년 05월',
#   'price': '16,920',
#   'review': None},
#  {'title': '된다! 하루 5분 아이패드 기록 생활',
#   'writer': '희나 저',
#   'pub': '이지스퍼블리싱',
#   'pub_date': '2025년 04월',
#   'price': '16,200',
#   'review': '10.0'},
#  {'title': '무조건 쿠팡에서 팔아라 그래야 산다',
#   'writer': '하지혜, 오대장 저',
#   'pub': '우리네삶',
#   'pub_date': '2024년 10월',
#   'price': '21,600',
#   'review': '10.0'},
#  {'title': '랭체인 & 랭그래프로 AI 에이전트 개발하기',
#   'writer': '서지영 저',
#   'pub': '길벗',
#   'pub_date': '2025년 03월',
#   'price': '26,100',
#   'review': '10.0'},
#  {'title': '써니쌤과 함께 처음 시작하는 SNS 디자인 캔바',
#   'writer': '써니쌤 강성은 저',
#   'pub': '시원북스',
#   'pub_date': '2024년 12월',
#   'price': '17,820',
#   'review': '9.9'},
#  {'title': '하루 30분! 돈이 되는 네이버 블로그 with 챗GPT',
#   'writer': '조병옥(호모앤) 저',
#   'pub': '한빛미디어',
#   'pub_date': '2024년 10월',
#   'price': '16,200',
#   'review': '9.5'},
#  {'title': 'Clean Code 클린 코드',
#   'writer': '로버트 C. 마틴 저/박재호, 이해영 역',
#   'pub': '인사이트(insight)',
#   'pub_date': '2013년 12월',
#   'price': '29,700',
#   'review': '9.5'},
#  {'title': '윤성우의 열혈 C 프로그래밍',
#   'writer': '윤성우 저',
#   'pub': '오렌지미디어',
#   'pub_date': '2010년 11월',
#   'price': '22,500',
#   'review': '9.6'},
#  {'title': 'LLM 엔지니어링',
#   'writer': '폴 이우수틴, 막심 라본 저/조우철 역',
#   'pub': '한빛미디어',
#   'pub_date': '2025년 05월',
#   'price': '34,200',
#   'review': '10.0'},
#  {'title': '된다! 업무에 바로 쓰는 구글 활용법',
#   'writer': '이광희 저',
#   'pub': '이지스퍼블리싱',
#   'pub_date': '2025년 04월',
#   'price': '18,900',
#   'review': '10.0'},
#  {'title': 'AI 덕분에 오늘도 칼퇴합니다',
#   'writer': '박소이 저',
#   'pub': '비전코리아',
#   'pub_date': '2025년 05월',
#   'price': '15,120',
#   'review': '9.9'},
#  {'title': '현직 교사가 만든 업무자동화를 원하는 교사를 위한 찐 실전 챗GPT GPTs·미조우·제미나이 - 챗봇 만들기 생성형 AI 챗봇으로 수업 업무 박살 내기!',
#   'writer': '김요섭, 허영주, 조래정, 정재우 저',
#   'pub': '광문각출판미디어',
#   'pub_date': '2025년 04월',
#   'price': '15,000',
#   'review': '10.0'},
#  {'title': '미드저니 마스터 바이블',
#   'writer': '조남경 저',
#   'pub': '비엘북스',
#   'pub_date': '2025년 04월',
#   'price': '29,700',
#   'review': None},
#  {'title': '랭체인과 RAG로 배우는 실전 LLM 애플리케이션 개발',
#   'writer': '양기빈, 조국일, 장지선, 조수현 저',
#   'pub': '위키북스',
#   'pub_date': '2025년 04월',
#   'price': '25,200',
#   'review': '10.0'},
#  {'title': '유튜브 AI 성공 전략 : 쇼츠로 시작해 수익화까지',
#   'writer': '강민형 저',
#   'pub': '디지털북스',
#   'pub_date': '2025년 04월',
#   'price': '19,800',
#   'review': None},
#  {'title': '돈이 되는 AI 영상만들기',
#   'writer': '심동엽 저',
#   'pub': '비엘북스',
#   'pub_date': '2025년 03월',
#   'price': '19,800',
#   'review': '10.0'},
#  {'title': '벡터 데이터베이스 설계와 구축',
#   'writer': '송한림 저',
#   'pub': '아이리포',
#   'pub_date': '2025년 03월',
#   'price': '16,020',
#   'review': '10.0'},
#  {'title': '일잘러의 비밀, 챗GPT와 GPTs로 나만의 AI 챗봇 만들기',
#   'writer': '이경록, 김정욱 저',
#   'pub': '한빛미디어',
#   'pub_date': '2025년 02월',
#   'price': '21,600',
#   'review': '9.6'},
#  {'title': "띠웅's 타이포그래피 with 프로크리에이트",
#   'writer': '띠웅 저',
#   'pub': '다산스마트에듀',
#   'pub_date': '2025년 01월',
#   'price': '22,500',
#   'review': '9.9'},
#  {'title': '개발자를 위한 필수 수학',
#   'writer': '토머스 닐드 저/박해선 역',
#   'pub': '한빛미디어',
#   'pub_date': '2024년 06월',
#   'price': '27,000',
#   'review': '9.7'},
#  {'title': '챗GPT 프롬프트 120% 질문 기술',
#   'writer': 'ChatGPT 비즈니스 연구회 저/김모세 역',
#   'pub': '정보문화사',
#   'pub_date': '2024년 04월',
#   'price': '13,500',
#   'review': '9.7'},
#  {'title': 'Do it! C++ 완전 정복',
#   'writer': '조규남, 문종채 저',
#   'pub': '이지스퍼블리싱',
#   'pub_date': '2024년 03월',
#   'price': '28,800',
#   'review': '9.9'},
#  {'title': '컴퓨터 밑바닥의 비밀',
#   'writer': '루 샤오펑 저/김진호 역',
#   'pub': '길벗',
#   'pub_date': '2024년 03월',
#   'price': '29,700',
#   'review': '9.8'},
#  {'title': '마인크래프트 서바이벌 핸드북',
#   'writer': 'Mojang Studio 저/이주안 역',
#   'pub': '영진닷컴',
#   'pub_date': '2022년 12월',
#   'price': '10,800',
#   'review': '9.6'},
#  {'title': '코딩 자율학습 HTML + CSS + 자바스크립트',
#   'writer': '김기수 저',
#   'pub': '길벗',
#   'pub_date': '2022년 04월',
#   'price': '24,300',
#   'review': '9.8'},
#  {'title': '수학대백과사전',
#   'writer': '구라모토 다카후미 저/린커넥터 역',
#   'pub': '동양북스(동양books)',
#   'pub_date': '2020년 12월',
#   'price': '16,200',
#   'review': '9.6'},
#  {'title': '프리드버그 선형대수학',
#   'writer': '스티븐 H. 프리드버그, 아놀드 J. 인셀, 로렌스 E. 스펜스 저/한빛수학교재연구소 역/심형보 감수',
#   'pub': '한빛아카데미',
#   'pub_date': '2020년 06월',
#   'price': '35,000',
#   'review': '9.8'},
#  {'title': '밑바닥부터 시작하는 딥러닝 2',
#   'writer': '사이토 고키 저/개앞맵시 역',
#   'pub': '한빛미디어',
#   'pub_date': '2019년 05월',
#   'price': '26,100',
#   'review': '9.9'},
#  {'title': '혼자 만들면서 공부하는 딥러닝',
#   'writer': '박해선 저',
#   'pub': '한빛미디어',
#   'pub_date': '2025년 05월',
#   'price': '25,200',
#   'review': None},
#  {'title': '비트코인만 알고 블록체인은 모르는 당신에게',
#   'writer': '서울대학교 블록체인학회 디사이퍼 저',
#   'pub': '도서담',
#   'pub_date': '2025년 03월',
#   'price': '24,210',
#   'review': None},
#  {'title': '맛있는 디자인 포토샵&일러스트레이터 CC 2025',
#   'writer': '박정아, 윤이사라 저',
#   'pub': '한빛미디어',
#   'pub_date': '2025년 02월',
#   'price': '23,400',
#   'review': '10.0'},
#  {'title': '도덕적인 AI',
#   'writer': '월터 시넛 암스트롱, 재나 셰익 보그, 빈센트 코니처 저/박초월 역',
#   'pub': '김영사',
#   'pub_date': '2025년 01월',
#   'price': '19,800',
#   'review': '9.8'},
#  {'title': '혁펜하임의 Easy! 딥러닝',
#   'writer': '혁펜하임 저',
#   'pub': '북엔드',
#   'pub_date': '2024년 11월',
#   'price': '31,500',
#   'review': '9.8'},
#  {'title': '마인크래프트 건축 아이디어 북',
#   'writer': 'Mojang Studio 저/이주안 역',
#   'pub': '영진닷컴',
#   'pub_date': '2024년 03월',
#   'price': '22,500',
#   'review': '10.0'},
#  {'title': '오토캐드 40시간 완성',
#   'writer': '신동진 저',
#   'pub': '피앤피북',
#   'pub_date': '2024년 03월',
#   'price': '18,000',
#   'review': '10.0'},
#  {'title': '챗GPT로 만드는 주식 & 암호화폐 자동매매 시스템',
#   'writer': '설근민 저',
#   'pub': '제이펍',
#   'pub_date': '2023년 11월',
#   'price': '18,000',
#   'review': '9.7'},
#  {'title': '코딩 자율학습 나도코딩의 파이썬 입문',
#   'writer': '나도코딩 저',
#   'pub': '길벗',
#   'pub_date': '2023년 02월',
#   'price': '21,600',
#   'review': '9.8'},
#  {'title': '가상 면접 사례로 배우는 대규모 시스템 설계 기초',
#   'writer': '알렉스 쉬 저/이병준 역',
#   'pub': '인사이트(insight)',
#   'pub_date': '2021년 07월',
#   'price': '21,600',
#   'review': '9.4'},
#  {'title': '소프트웨어 테스트 전문가(CSTS) 가이드',
#   'writer': '한국정보통신기술협회(TTA) 저',
#   'pub': '홍릉',
#   'pub_date': '2021년 04월',
#   'price': '33,000',
#   'review': '7.5'},
#  {'title': '좋은 사진을 만드는 정승익의 사진 구도',
#   'writer': '정승익 저',
#   'pub': '한빛미디어',
#   'pub_date': '2013년 11월',
#   'price': '17,100',
#   'review': '9.4'},
#  {'title': '알고리즘 문제 해결 전략 세트',
#   'writer': '구종만 저',
#   'pub': '인사이트(insight)',
#   'pub_date': '2012년 11월',
#   'price': '45,000',
#   'review': '9.7'},
#  {'title': '공자가 AI 시대를 산다면',
#   'writer': '김준태 저',
#   'pub': '한겨레출판',
#   'pub_date': '2025년 04월',
#   'price': '16,200',
#   'review': '10.0'},
#  {'title': '랭체인으로 RAG 개발하기: VectorRAG & GraphRAG',
#   'writer': '서지영 저',
#   'pub': '길벗',
#   'pub_date': '2025년 04월',
#   'price': '26,100',
#   'review': None},
#  {'title': '디자인 감각 제대로 키우는 법',
#   'writer': '가마타 다카시 저/김현미 역',
#   'pub': '시프트',
#   'pub_date': '2025년 05월',
#   'price': '17,100',
#   'review': '10.0'},
#  {'title': '실전 ComfyUI',
#   'writer': '우희철 저',
#   'pub': '디지털북스',
#   'pub_date': '2025년 04월',
#   'price': '22,500',
#   'review': None},
#  {'title': '감으로 하는 브랜딩은 끝났다',
#   'writer': '조연심 저',
#   'pub': '힘찬북스',
#   'pub_date': '2025년 03월',
#   'price': '19,800',
#   'review': '9.7'},
#  {'title': '맛있는 디자인 프리미어 프로&애프터 이펙트 CC 2025',
#   'writer': '심수진, 윤성우, 이수정 저',
#   'pub': '한빛미디어',
#   'pub_date': '2025년 02월',
#   'price': '24,300',
#   'review': '9.8'},
#  {'title': '이토록 쉬운 RAG 시스템 구축을 위한 랭체인 실전 가이드',
#   'writer': '윤성재 저',
#   'pub': '루비페이퍼',
#   'pub_date': '2024년 10월',
#   'price': '23,400',
#   'review': '9.9'},
#  {'title': 'AI 영화 제작',
#   'writer': '민지영, 문수민, 전은재, 앤미디어 저',
#   'pub': '길벗',
#   'pub_date': '2024년 11월',
#   'price': '24,300',
#   'review': '9.9'},
#  {'title': '인공지능이 다 해주는 브루 Vrew 영상 편집',
#   'writer': '지현이 저/브루 개발팀 감수',
#   'pub': '시프트',
#   'pub_date': '2024년 10월',
#   'price': '18,000',
#   'review': '9.4'},
#  {'title': '2022 개정 교육과정 평가, AI로 날개를 달다 (개념기반 교육과정)',
#   'writer': '지미정, 오한나, 노명호, 권의선, 김영수 저 외 4명\r\n                                        \n정보 더 보기/감추기\n\n\n\n지미정\n오한나\n노명호\n권의선\n김영수\n이진원\n장희영\n소민영\n조보현',
#   'pub': '\n정보 더 보기/감추기\n\n\n\n지미정\n오한나\n노명호\n권의선\n김영수\n이진원\n장희영\n소민영\n조보현\n\n\n\n',
#   'pub_date': '정보 더 보기/감추기',
#   'price': '18,900',
#   'review': '9.9'},
#  {'title': 'LLM을 활용한 실전 AI 애플리케이션 개발',
#   'writer': '허정준 저/정진호 그림/박재호 감수',
#   'pub': '책만',
#   'pub_date': '2024년 07월',
#   'price': '28,800',
#   'review': '9.3'},
#  {'title': '최고의 프롬프트 엔지니어링 강의',
#   'writer': '김진중 저',
#   'pub': '리코멘드',
#   'pub_date': '2024년 06월',
#   'price': '21,600',
#   'review': '7.5'},
#  {'title': '혼자 공부하는 네트워크',
#   'writer': '강민철 저',
#   'pub': '한빛미디어',
#   'pub_date': '2024년 04월',
#   'price': '25,200',
#   'review': '9.8'},
#  {'title': '마인크래프트 미니게임 만들기',
#   'writer': '우마공 운영진 저',
#   'pub': '영진닷컴',
#   'pub_date': '2024년 02월',
#   'price': '15,120',
#   'review': '9.9'},
#  {'title': '챗GPT 교사 마스터 플랜',
#   'writer': '한민철 저',
#   'pub': '책바세',
#   'pub_date': '2023년 10월',
#   'price': '21,600',
#   'review': '9.7'},
#  {'title': '마인크래프트 핸드북 컬렉션',
#   'writer': 'Mojang Studio 저/이주안 역',
#   'pub': '영진닷컴',
#   'pub_date': '2023년 09월',
#   'price': '37,800',
#   'review': '10.0'},
#  {'title': '이것이 C#이다',
#   'writer': '박상현 저',
#   'pub': '한빛미디어',
#   'pub_date': '2023년 05월',
#   'price': '32,400',
#   'review': '9.4'}]

# %%
conn = psycopg2.connect(
    host=os.getenv("DB_HOST"),
    database=os.getenv("DB_NAME"),
    user=os.getenv("DB_USER"),
    password=os.getenv("DB_PASSWORD")
)
cur = conn.cursor()

# %%
q = '''
      SELECT book_id
      FROM book
      ORDER BY book_id DESC
      LIMIT 1
    '''

cur.execute(q)
last_index = cur.fetchone()[0]

# %%
q = '''
      INSERT INTO book(
      book_id, title, writer, pub, pub_date, review, price)
      VALUES (%s, %s, %s, %s, %s, %s, %s);
    '''

for ix, book in enumerate(book_list, last_index+1):
  cur.execute(q, (ix, book['title'], book['writer'], book['pub'], 
                  book['pub_date'], book['review'], book['price'].replace(',', '')))

conn.commit()  # 변경사항을 커밋
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# Cell In[60], line 8
#       1 q = '''
#       2       INSERT INTO book(
#       3       book_id, title, writer, pub, pub_date, review, price)
#       4       VALUES (%s, %s, %s, %s, %s, %s, %s);
#       5     '''
#       7 for ix, book in enumerate(book_list, 3):
# ----> 8   cur.execute(q, (ix, book['title'], book['writer'], book['pub'],
#       9                   book['pub_date'], book['review'], book['price'].replace(',', '')))
#      11 conn.commit()  # 변경사항을 커밋
#
# UniqueViolation: duplicate key value violates unique constraint "book_pkey"
# DETAIL:  Key (book_id)=(3) already exists.

# %%
# 결과 출력
pd.read_sql("SELECT * FROM book", conn)
# Out:
# /var/folders/xw/2xv7101s71s4jcv2bxrz47rh0000gn/T/ipykernel_9664/3209197855.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("SELECT * FROM book", conn)
#      book_id                   title                 writer       pub  \
# 0          1               test book            test writer  test pub
# 1          2               test book            test writer  test pub
# 2          3          커서 AI 트렌드&활용백과                  서승완 저     스마트북스
# 3          4  된다! 조회수 터지는 유튜브 쇼츠 만들기                  최지영 저   이지스퍼블리싱
# 4          5  이게 되네? 챗GPT 미친 활용법 71제                  오힘찬 저      골든래빗
# ..       ...                     ...                    ...       ...
# 117      118            혼자 공부하는 네트워크                  강민철 저     한빛미디어
# 118      119         마인크래프트 미니게임 만들기              우마공 운영진 저      영진닷컴
# 119      120          챗GPT 교사 마스터 플랜                  한민철 저       책바세
# 120      121          마인크래프트 핸드북 컬렉션  Mojang Studio 저/이주안 역      영진닷컴
# 121      122                이것이 C#이다                  박상현 저     한빛미디어
#
#        pub_date  review  price
# 0    2023-10-01     9.2  15000
# 1    2023-10-01     NaN  15000
# 2     2025년 03월     9.6  22500
# 3     2025년 04월    10.0  19800
# 4     2025년 01월     9.6  21600
# ..          ...     ...    ...
# 117   2024년 04월     9.8  25200
# 118   2024년 02월     9.9  15120
# 119   2023년 10월     9.7  21600
# 120   2023년 09월    10.0  37800
# 121   2023년 05월     9.4  32400
#
# [122 rows x 7 columns]

# %%
cur.close()
cr.close()
conn.close()
