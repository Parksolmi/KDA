# %% [markdown]
# ---
# # 39. **친구 목록 관리하기!** | 문자열과 리스트 활용
#
# 친구 관리 앱을 만들고 있습니다.
# 사용자가 저장한 친구 정보는 문자열로 구성되어 있고, 친구 이름은 쉼표로 구분되어 있습니다.
# 앱에서는 다음과 같은 기능을 제공합니다:
#
# - 이름에 있는 앞뒤 공백을 제거
# - 친구 이름이 목록에 없다면 추가
# - 친구 이름이 목록에 있다면 제거
# - 특정 친구가 몇 번 등장했는지 세기
# - 첫 등장 위치 찾기
# - 정리된 친구 목록을 문자열로 변환
#
# 아래 지시사항에 따라 프로그램을 완성해 봅시다.
#
#
# ### 🤔 **지시사항**
#
# 1. `friends_str` 변수에 문자열 `" Alice , Bob,  Charlie, Alice  ,Bob "`가 저장되어 있습니다.
# 2. 이 문자열을 `split()`을 이용해 친구 이름 리스트로 바꾸어 `split_names` 리스트 변수에 저장합니다. (쉼표 기준)
# 3. 각 이름의 앞뒤 공백을 `strip()`으로 제거하여 `friends` 리스트 변수를 만듭니다.
# 4. 새로운 친구 `"David"`가 있다면 제거하고, 없다면 추가합니다.
# 5. `"Alice"`가 친구 목록에 몇 번 등장하는지 세어 `alice_count` 변수에 저장합니다.
# 6. `"Bob"`이 처음 등장하는 인덱스를 `bob_index`에 저장합니다.
# 7. `friends` 리스트를 다시 쉼표(', ')로 연결해 문자열로 바꾸고 `result_str`에 저장합니다.
#
# ### 🍎 **출력 예시**
# ```python
# 2
# 1
# Alice, Bob, Charlie, Alice, Bob, David
# ```
#
# ### 😆 **Hints!**
# - 문자열 메서드: `split`, `strip`, `join`, `find`
# - 리스트 메서드: `append`, `pop`, `count`, `index`

# %%
friends_str = " Alice , Bob,  Charlie, Alice  ,Bob "

# 문자열을 친구 이름 리스트로 바꾸고(split_names) 공백을 제거(friends)합니다.
split_names = None
friends = None

# 새로운 친구 "David"가 있다면 제거하고, 없다면 추가합니다.

# "Alice"가 친구 목록에 몇 번 등장하는지 세어 alice_count 변수에 저장합니다.
alice_count = None

# "Bob"이 처음 등장하는 인덱스를 bob_index에 저장합니다.
bob_index = None

# friends 리스트를 다시 쉼표(', ')로 연결해 문자열로 바꾸고 result_str에 저장합니다.
result_str = None

# 결과를 출력합니다
print(alice_count)
print(bob_index)
print(result_str)

# %% [markdown]
# ---
# # 40. **함수를 더 간단하게!** | lambda 표현식 활용하기
#
# 일반적인 함수 정의(def)를 lambda 표현식으로 변환하는 연습을 해봅시다.
# lambda는 간단한 함수를 한 줄로 표현할 수 있게 해주는 파이썬의 특별한 기능입니다.
#
# 아래 주어진 일반 함수들을 lambda 표현식으로 바꿔보세요.
#
# ### 🤔 **지시사항**
# 1. 이름의 마지막 글자를 반환하는 함수 `get_last_char`를 lambda로 변환하여 `last_char_lambda`에 저장하세요.
# 2. 숫자가 짝수인지 확인하는 함수 `is_even`을 lambda로 변환하여 `even_lambda`에 저장하세요.
# 3. 세 수의 평균을 계산하는 함수 `calculate_average`를 lambda로 변환하여 `avg_lambda`에 저장하세요.
# 4. 두 문자열을 받아서 길이가 더 긴 문자열을 반환하는 함수 `get_longer`를 lambda로 변환하여 `longer_lambda`에 저장하세요. (길이가 같으면 첫 번째 문자열 반환)
# 5. 각각의 lambda 함수를 호출하여 결과를 확인해보세요.
#
# ### 🍎 **출력 예시**
# ```
# n
# True
# 20.0
# python
# ```
#
# ### 😆 **Hints!**
# - lambda 함수는 `lambda 매개변수: 반환값(표현식)` 형식으로 작성합니다.
# - lambda는 return 문을 사용하지 않습니다. 표현식의 결과가 자동으로 반환됩니다.

# %%
def get_last_char(text):
    return text[-1]

def is_even(x):
    return x % 2 == 0

def calculate_average(x, y, z):
    return (x + y + z) / 3

def get_longer(str1, str2):
    if len(str1) >= len(str2):
        return str1
    return str2

# 위 함수들을 lambda 표현식으로 변환하여 아래 변수들에 저장하세요.
last_char_lambda = None
even_lambda = None
avg_lambda = None
longer_lambda = None

# 결과 확인
print(last_char_lambda('Python'))
print(even_lambda(6))
print(avg_lambda(10, 20, 30))
print(longer_lambda('python', 'code'))

# %% [markdown]
# ---
# # 41. **함수의 동작 확인하기** | assert를 활용한 함수 검증
#
# 프로그래밍에서는 함수가 의도한 대로 동작하는지 확인하는 것이 매우 중요합니다.
# 이번에는 assert를 사용하여 우리가 만든 lambda 함수가 원래의 함수와 동일하게 동작하는지 검증해보겠습니다.
#
# ### 🤔 **지시사항**
# 1. 37번 문제에서 정의한 lambda 함수들(`last_char_lambda`, `even_lambda`, `avg_lambda`, `longer_lambda`)을 정의하는 코드를 복사해서 붙여넣으세요.
# 2. 각 lambda 함수가 원본 함수와 동일한 결과를 반환하는지 assert를 사용하여 검증하세요. 에러메세지도 출력합니다.
# 3. 의도적으로 잘못된 결과를 반환하는 lambda 함수를 만들어보고, assert가 어떻게 동작하는지 확인해보세요.
#
# ### 🍎 **출력 예시**
# * AssertionError 발생 시 출력 예시입니다.
# ```python
# AssertionError: even_lambda 함수가 올바르지 않습니다.
# ```
#
# ### 😆 **Hints!**
# - assert 문은 `assert 조건식, "오류 메시지"` 형태로 작성합니다.
# - assert는 조건식이 False일 때 AssertionError를 발생시킵니다.
# - 여러 가지 테스트 케이스로 검증해보면 더 확실합니다.

# %%
# 37번의 일반 함수들
def get_last_char(text):
    return text[-1]

def is_even(x):
    return x % 2 == 0

def calculate_average(x, y, z):
    return (x + y + z) / 3

def get_longer(str1, str2):
    if len(str1) >= len(str2):
        return str1
    return str2

# 아래에 37번에서 정의한 lambda 함수들을 복사해서 붙여넣으세요.



# 원본 함수와 lambda 함수의 실행 결과를 비교해보세요. 결과가 다르면 해당 Lambda 함수가 올바르지 않다는 에러 메시지를 출력합니다.

# %% [markdown]
# ---
# # 42. **성적순으로 정렬하기** | lambda와 sorted
#
# 파이썬의 sorted 함수는 key 매개변수를 통해 정렬 기준을 지정할 수 있습니다.
# 이때 lambda 함수를 활용하면 간단하게 다양한 정렬 기준을 구현할 수 있습니다.
#
# 학생들의 성적 데이터를 여러 가지 기준으로 정렬해보며 lambda와 sorted의 활용법을 익혀봅시다.
#
# ### 🤔 **지시사항**
# 1. 주어진 학생 정보 리스트를 이용해 다음 정렬을 수행하세요:
#    - 점수를 기준으로 내림차순 정렬 (`score_desc`)
#    - 이름의 길이를 기준으로 오름차순 정렬 (`name_len_asc`)
#    - 나이를 기준으로 오름차순, 같은 나이는 점수를 기준으로 내림차순 정렬 (`age_score`)
#
# ### 🍎 **출력 예시**
# ```python
# # score_desc 출력
# [('David', 19, 95), ('Alice', 20, 92), ('Charlie', 19, 85), ('Bob', 18, 80)]
#
# # name_len_asc 출력
# [('Bob', 18, 80), ('Alice', 20, 92), ('David', 19, 95), ('Charlie', 19, 85)]
#
# # age_score 출력
# [('Bob', 18, 80), ('David', 19, 95), ('Charlie', 19, 85), ('Alice', 20, 92)]
# ```
#
# ### 😆 **Hints!**
# - sorted의 key 매개변수에는 정렬 기준이 되는 함수를 전달합니다.
# - lambda를 사용하여 튜플의 특정 위치 값을 반환할 수 있습니다.
# - 여러 기준으로 정렬할 때는 튜플을 반환하는 lambda를 사용합니다.

# %%
# 학생 정보 리스트 (이름, 나이, 점수)
students = [
    ('Peterpan', 20, 92),
    ('Wendy', 18, 80),
    ('John', 16, 85),
    ('Tinkerbell', 19, 95)
]

# 1. 점수를 기준으로 내림차순 정렬
score_desc = None

# 2. 이름의 길이를 기준으로 오름차순 정렬
name_len_asc = None

# 3. 나이 오름차순, 같은 나이는 점수 내림차순 정렬
age_score = None

# 결과 출력
print("\n점수 내림차순:")
print(score_desc)

print("\n이름 길이 오름차순:")
print(name_len_asc)

print("\n나이 오름차순(같은 나이는 점수 내림차순):")
print(age_score)

# %% [markdown]
# ---
# # 43. **데이터 정제하기** | filter와 Truthy/Falsy
#
# 파이썬에서는 모든 객체가 불리언 문맥에서 참(Truthy) 또는 거짓(Falsy)으로 평가됩니다.
# 일반적으로 비어있는 컨테이너([], '', {}, set()), None, 0은 Falsy로 평가되고,
# 그 외의 값들은 Truthy로 평가됩니다.
#
# Truthy한 값만 걸러내는 `filter` 함수의 특성을 활용하여 데이터를 정제해봅시다.
#
# ### 🤔 **지시사항**
# **모두 `filter()`함수를 사용해서 풀어 보세요.**
# 1. 숫자 리스트 `numbers`에서 짝수는 제거해 `remove_even`에 저장하세요.
# 1. 문자열 리스트 `strings`에서 비어 있거나 공백 뿐인 문자열은 제거해 `remove_empty_strings`에 저장하세요.
# 3. 사용자 정보 리스트 `users`에서 이메일이 없는(빈 문자열) 사용자를 제거해 `remove_no_email`에 저장하세요.
#
# ### 🍎 **출력 예시**
# ```
# [393, 49, 31, 57, 39]
# ['hello', 'world', 'python']
# [('Kim', 'kim@email.com'), ('Park', 'park@email.com')]
# ```
#
# ### 😆 **Hints!**
# - filter() 함수는 첫 번째 인자로 함수를, 두 번째 인자로 순회 가능한 객체를 받습니다.
# - lambda 함수에서 조건식을 생략하면 값 자체의 Truthy/Falsy를 판단합니다.
# - filter() 결과를 list()로 감싸서 리스트로 변환할 수 있습니다.

# %%
## 1. 짝수 제거
numbers = [4, 393, 302, 49, 40, 31, 57, 39]
remove_even = None
print(list(remove_even))

## 2. 비어 있거나 공백 뿐인 문자열 제거
strings = ['', 'hello', '   ', 'world', '', 'python', '  ', '']
remove_empty_strings = None
print(remove_empty_strings)

## 3. 이메일이 없는 사용자 제거
users = [
    ('Kim', 'kim@email.com'),
    ('Lee', ''),
    ('Park', 'park@email.com'),
    ('Choi', '')
]
remove_no_email = None
print(remove_no_email)

# %% [markdown]
# ---
# # 44. **쇼핑 목록 만들기** | 리스트 컴프리헨션
#
# 온라인 쇼핑몰의 상품 데이터를 처리하면서 리스트 컴프리헨션을 연습해봅시다.
# 기존의 for 반복문을 리스트 컴프리헨션으로 변환하는 과정을 통해,
# 더 간단하고 효율적인 코드 작성 방법을 익혀보겠습니다.
#
# ### 🤔 **지시사항**
# 1. 상품 가격에 20% 할인을 적용한 새로운 리스트를 만드세요. <br/>
# 1-1. 일반 for문으로 작성한 코드를 리스트 컴프리헨션으로 변환하세요.
#
# 2. 1만원 이상의 상품들만 모아서 새로운 리스트를 만드세요. <br/>
# 2-1. 일반 for문과 if문으로 작성한 코드를 리스트 컴프리헨션으로 변환하세요.
#
# 3. 2만원 이상인 상품은 20% 할인, 2만원 미만인 상품은 10% 할인을 적용한 리스트를 만드세요. <br/>
# 3-1.일반 for문과 if-else문으로 작성한 코드를 리스트 컴프리헨션으로 변환하세요.
#
# ### 🍎 **출력 예시**
# ```python
# # 1번 문제 출력
# 원래 가격: [25000, 12000, 8900, 32000, 15600]
# 할인 가격: [20000, 9600, 7120, 25600, 12480]
#
# # 2번 문제 출력
# 1만원 이상 상품: [25000, 12000, 32000, 15600]
#
# # 3번 문제 출력
# 차등 할인 적용: [20000, 10800, 8010, 25600, 14040]
# ```
#
# ### 😆 **Hints!**
# - 리스트 컴프리헨션 기본 형식: `[표현식 for 항목 in 시퀀스]`
# - 조건문 추가 형식: `[표현식 for 항목 in 시퀀스 if 조건식]`
# - 조건문과 else 추가 형식: `[표현식1 if 조건식 else 표현식2 for 항목 in 시퀀스]`

# %%
## 상품 가격 리스트
prices = [25000, 12000, 8900, 32000, 15600]

## 1. 20% 할인 적용하기
# 1-1. 일반 for문으로 작성
sale_prices_for = []
for price in prices:
    ...

# 1-2. 리스트 컴프리헨션으로 작성
sale_prices = None

# 1-3. 두 리스트 비교하기
print(f"일반for문: {sale_prices_for}")
print(f"컴프리헨션: {sale_prices}")

## 2. 1만원 이상 상품 필터링
# 2-1. 일반 for문으로 작성
expensive_for = []
for price in prices:
    ...

# 2-2. 리스트 컴프리헨션으로 작성
expensive = None

# 2-3. 두 리스트 비교하기
print(f"일반for문: {expensive_for}")
print(f"컴프리헨션: {expensive}")

## 3. 차등 할인 적용하기
# 3-1. 일반 for문으로 작성
dynamic_sale_for = []
...

# 3-2. 리스트 컴프리헨션으로 변환
dynamic_sale = None

# 3-3. 두 리스트 비교하기
print(f"일반for문: {dynamic_sale_for}")
print(f"컴프리헨션: {dynamic_sale}")
